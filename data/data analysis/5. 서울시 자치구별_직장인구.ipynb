# %%
# 서울시 자치구별 직장인구 데이터 가져오기
# 총 34,483개의 레코드

import pandas as pd

data = pd.read_csv('../raw data/서울시 우리마을가게 상권분석서비스(상권-직장인구).csv', encoding='cp949')     # csv 파일 읽기
data.head()          # 상위 5개 확인
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    기준_년월_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드                 상권_코드_명  \
# 0      2022         2        U       관광특구  1001496             강남 마이스 관광특구
# 1      2022         2        U       관광특구  1001495                 잠실 관광특구
# 2      2022         2        U       관광특구  1001494              종로?청계 관광특구
# 3      2022         2        U       관광특구  1001493            동대문패션타운 관광특구
# 4      2022         2        U       관광특구  1001492  명동 남대문 북창동 다동 무교동 관광특구
#
#   상권_구분_자치구별  총_직장_인구_수  남성_직장_인구_수  여성_직장_인구_수  ...  남성연령대_30_직장_인구_수  \
# 0        강남구      15904        8904        7000  ...              3361
# 1        송파구      24375       14199       10176  ...              4186
# 2        종로구      32935       17150       15785  ...              4911
# ...

# %%
data.tail()
# Out:
#        기준_년월_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드  상권_코드_명 상권_구분_자치구별  \
# 34479      2017         2        A       골목상권  2110005      세검정        NaN
# 34480      2017         2        A       골목상권  2110004   대신고등학교        NaN
# 34481      2017         2        A       골목상권  2110003  세검정초등학교        NaN
# 34482      2017         2        A       골목상권  2110002  독립문역 1번        NaN
# 34483      2017         2        A       골목상권  2110001   이북5도청사        NaN
#
#        총_직장_인구_수  남성_직장_인구_수  여성_직장_인구_수  ...  남성연령대_30_직장_인구_수  \
# 34479        445         159         286  ...                38
# 34480         41          14          27  ...                 1
# 34481        144          79          65  ...                10
# 34482        583         152         431  ...                29
# 34483        276         158         118  ...                37
#
#        남성연령대_40_직장_인구_수  남성연령대_50_직장_인구_수  남성연령대_60_이상_직장_인구_수  \
# ...

# %%
# 2022년 2분기 데이터 추출
data = data[data['기준_년월_코드']==2022]
data = data[data['기준_분기_코드']==2]
data

# 총 1,630개 레코드
# Out:
#       기준_년월_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드                 상권_코드_명  \
# 0         2022         2        U       관광특구  1001496             강남 마이스 관광특구
# 1         2022         2        U       관광특구  1001495                 잠실 관광특구
# 2         2022         2        U       관광특구  1001494              종로?청계 관광특구
# 3         2022         2        U       관광특구  1001493            동대문패션타운 관광특구
# 4         2022         2        U       관광특구  1001492  명동 남대문 북창동 다동 무교동 관광특구
# ...        ...       ...      ...        ...      ...                     ...
# 1625      2022         2        A       골목상권  2110005                     세검정
# 1626      2022         2        A       골목상권  2110004                  대신고등학교
# 1627      2022         2        A       골목상권  2110003                 세검정초등학교
# 1628      2022         2        A       골목상권  2110002                 독립문역 1번
# 1629      2022         2        A       골목상권  2110001                  이북5도청사
#
# ...

# %%
data.columns
# Out:
# Index(['기준_년월_코드', '기준_분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명',
#        '상권_구분_자치구별', '총_직장_인구_수', '남성_직장_인구_수', '여성_직장_인구_수', '연령대_10_직장_인구_수',
#        '연령대_20_직장_인구_수', '연령대_30_직장_인구_수', '연령대_40_직장_인구_수', '연령대_50_직장_인구_수',
#        '연령대_60_이상_직장_인구_수', '남성연령대_10_직장_인구_수', '남성연령대_20_직장_인구_수',
#        '남성연령대_30_직장_인구_수', '남성연령대_40_직장_인구_수', '남성연령대_50_직장_인구_수',
#        '남성연령대_60_이상_직장_인구_수', '여성연령대_10_직장_인구_수', '여성연령대_20_직장_인구_수',
#        '여성연령대_30_직장_인구_수', '여성연령대_40_직장_인구_수', '여성연령대_50_직장_인구_수',
#        '여성연령대_60_이상_직장_인구_수'],
#       dtype='object')

# %%
# 필요한 열 추출

data = data[['기준_년월_코드', '기준_분기_코드','상권_구분_코드_명','상권_코드_명','상권_구분_자치구별','총_직장_인구_수','연령대_20_직장_인구_수', '연령대_30_직장_인구_수']]
data
# Out:
#       기준_년월_코드  기준_분기_코드 상권_구분_코드_명                 상권_코드_명 상권_구분_자치구별  \
# 0         2022         2       관광특구             강남 마이스 관광특구        강남구
# 1         2022         2       관광특구                 잠실 관광특구        송파구
# 2         2022         2       관광특구              종로?청계 관광특구        종로구
# 3         2022         2       관광특구            동대문패션타운 관광특구       동대문구
# 4         2022         2       관광특구  명동 남대문 북창동 다동 무교동 관광특구         중구
# ...        ...       ...        ...                     ...        ...
# 1625      2022         2       골목상권                     세검정        종로구
# 1626      2022         2       골목상권                  대신고등학교        종로구
# 1627      2022         2       골목상권                 세검정초등학교        종로구
# 1628      2022         2       골목상권                 독립문역 1번        종로구
# 1629      2022         2       골목상권                  이북5도청사        종로구
#
#       총_직장_인구_수  연령대_20_직장_인구_수  연령대_30_직장_인구_수
# 0         15904            3513            6185
# ...

# %%
# 자치구별 집계
# 20대 직장인구
grouped_20s = data.groupby('상권_구분_자치구별')['연령대_20_직장_인구_수'].sum()
grouped_20s
# Out:
# 상권_구분_자치구별
# 강남구     150410
# 강동구       5317
# 강북구       1486
# 강서구       5707
# 관악구       3539
# 광진구       7645
# 구로구      16417
# 금천구      18871
# 노원구       1993
# 도봉구       1601
# 동대문구      9219
# 동작구       6829
# 마포구      18501
# 서대문구      5772
# 서초구      47964
# 성동구       9533
# 성북구       5007
# 송파구      32007
# 양천구       5044
# 영등포구     31742
# 용산구      33761
# 은평구       2951
# 종로구      39280
# 중구       88410
# 중랑구       1870
# Name: 연령대_20_직장_인구_수, dtype: int64

# %%
# 자치구별 집계
# 30대 직장인구
grouped_30s = data.groupby('상권_구분_자치구별')['연령대_30_직장_인구_수'].sum()
grouped_30s
# Out:
# 상권_구분_자치구별
# 강남구     220309
# 강동구       7961
# 강북구       2512
# 강서구       9059
# 관악구       5326
# 광진구      10609
# 구로구      26880
# 금천구      29860
# 노원구       2746
# 도봉구       3031
# 동대문구     12058
# 동작구      11111
# 마포구      26901
# 서대문구      7085
# 서초구      69121
# 성동구      13184
# 성북구      10281
# 송파구      49794
# 양천구       8489
# 영등포구     52140
# 용산구      45836
# 은평구       4584
# 종로구      66416
# 중구      113956
# 중랑구       3105
# Name: 연령대_30_직장_인구_수, dtype: int64

# %%
# 타입 확인
type(grouped_20s)
# Out:
# pandas.core.series.Series

# %%
# 타입 변환 Series -> DataFrame
pd.DataFrame(grouped_20s)
# Out:
#             연령대_20_직장_인구_수
# 상권_구분_자치구별
# 강남구                 150410
# 강동구                   5317
# 강북구                   1486
# 강서구                   5707
# 관악구                   3539
# 광진구                   7645
# 구로구                  16417
# 금천구                  18871
# 노원구                   1993
# 도봉구                   1601
# 동대문구                  9219
# 동작구                   6829
# 마포구                  18501
# 서대문구                  5772
# 서초구                  47964
# 성동구                   9533
# 성북구                   5007
# 송파구                  32007
# 양천구                   5044
# 영등포구                 31742
# 용산구                  33761
# 은평구                   2951
# 종로구                  39280
# 중구                   88410
# 중랑구                   1870

# %%
type(grouped_30s)
pd.DataFrame(grouped_30s)
# Out:
#             연령대_30_직장_인구_수
# 상권_구분_자치구별
# 강남구                 220309
# 강동구                   7961
# 강북구                   2512
# 강서구                   9059
# 관악구                   5326
# 광진구                  10609
# 구로구                  26880
# 금천구                  29860
# 노원구                   2746
# 도봉구                   3031
# 동대문구                 12058
# 동작구                  11111
# 마포구                  26901
# 서대문구                  7085
# 서초구                  69121
# 성동구                  13184
# 성북구                  10281
# 송파구                  49794
# 양천구                   8489
# 영등포구                 52140
# 용산구                  45836
# 은평구                   4584
# 종로구                  66416
# 중구                  113956
# 중랑구                   3105

# %%
# 열 merge
grouped = pd.merge(grouped_20s, grouped_30s, on='상권_구분_자치구별')
grouped
# Out:
#             연령대_20_직장_인구_수  연령대_30_직장_인구_수
# 상권_구분_자치구별
# 강남구                 150410          220309
# 강동구                   5317            7961
# 강북구                   1486            2512
# 강서구                   5707            9059
# 관악구                   3539            5326
# 광진구                   7645           10609
# 구로구                  16417           26880
# 금천구                  18871           29860
# 노원구                   1993            2746
# 도봉구                   1601            3031
# 동대문구                  9219           12058
# 동작구                   6829           11111
# 마포구                  18501           26901
# 서대문구                  5772            7085
# 서초구                  47964           69121
# 성동구                   9533           13184
# 성북구                   5007           10281
# 송파구                  32007           49794
# 양천구                   5044            8489
# 영등포구                 31742           52140
# ...

# %%
# csv 파일 저장
grouped.to_csv("working population.csv",encoding='utf8')

# %%
import pandas as pd
data = pd.read_csv('working population.csv',encoding='utf8')
data
# Out:
#    상권_구분_자치구별  연령대_20_직장_인구_수  연령대_30_직장_인구_수
# 0         강남구          150410          220309
# 1         강동구            5317            7961
# 2         강북구            1486            2512
# 3         강서구            5707            9059
# 4         관악구            3539            5326
# 5         광진구            7645           10609
# 6         구로구           16417           26880
# 7         금천구           18871           29860
# 8         노원구            1993            2746
# 9         도봉구            1601            3031
# 10       동대문구            9219           12058
# 11        동작구            6829           11111
# 12        마포구           18501           26901
# 13       서대문구            5772            7085
# 14        서초구           47964           69121
# 15        성동구            9533           13184
# 16        성북구            5007           10281
# 17        송파구           32007           49794
# 18        양천구            5044            8489
# ...

# %%
# 합계 열 추가
sum = data.sum(axis=1)
# Out:
# /var/folders/2x/pptt888d2_x9jxvslsglvm0w0000gn/T/ipykernel_79453/258698233.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sum = data.sum(axis=1)

# %%
data['합계'] = sum
data
# Out:
#    상권_구분_자치구별  연령대_20_직장_인구_수  연령대_30_직장_인구_수      합계
# 0         강남구          150410          220309  370719
# 1         강동구            5317            7961   13278
# 2         강북구            1486            2512    3998
# 3         강서구            5707            9059   14766
# 4         관악구            3539            5326    8865
# 5         광진구            7645           10609   18254
# 6         구로구           16417           26880   43297
# 7         금천구           18871           29860   48731
# 8         노원구            1993            2746    4739
# 9         도봉구            1601            3031    4632
# 10       동대문구            9219           12058   21277
# 11        동작구            6829           11111   17940
# 12        마포구           18501           26901   45402
# 13       서대문구            5772            7085   12857
# 14        서초구           47964           69121  117085
# 15        성동구            9533           13184   22717
# ...

# %%
# 인구수 합계 기준으로 정렬
sorted = data.sort_values(by=['합계'], ascending=False)
sorted
# Out:
#    상권_구분_자치구별  연령대_20_직장_인구_수  연령대_30_직장_인구_수      합계
# 0         강남구          150410          220309  370719
# 23         중구           88410          113956  202366
# 14        서초구           47964           69121  117085
# 22        종로구           39280           66416  105696
# 19       영등포구           31742           52140   83882
# 17        송파구           32007           49794   81801
# 20        용산구           33761           45836   79597
# 7         금천구           18871           29860   48731
# 12        마포구           18501           26901   45402
# 6         구로구           16417           26880   43297
# 15        성동구            9533           13184   22717
# 10       동대문구            9219           12058   21277
# 5         광진구            7645           10609   18254
# 11        동작구            6829           11111   17940
# 16        성북구            5007           10281   15288
# 3         강서구            5707            9059   14766
# ...

# %%
# 데이터 시각화
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = "AppleGothic"             # 한글 폰트 설정

# 누적 막대 그래프로 나타내기 
ax = sorted.plot.bar(x='상권_구분_자치구별',y={'연령대_20_직장_인구_수','연령대_30_직장_인구_수'},
                     fontsize=17,rot=40,figsize=(20,10),stacked=True)    
ax.set_title('서울시 20,30대 직장인구 수',fontsize=25)
ax.legend(fontsize=17)
plt.show()
