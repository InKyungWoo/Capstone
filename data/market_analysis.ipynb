# %%
import csv

f = open('market.csv', encoding='UTF8')    # 저장된 파일 불러오기
data = csv.reader(f)

for row in data:
    print(row)
f.close()
# Out:
# ['상호명', '지역(도)', '지역(시)', '지역(구)', '기본 메뉴 가격', '베이커리 여부', '상권']
# ['카페 프로틴 나우', '서울', '서울', '송파구', '6800', 'O', '주거단지']
# ['3H 프로틴카페', '서울', '서울', '중구', '7000', 'O', '상업단지']
# ['프로틴퀸u역삼', '서울', '서울', '강남구', '7000', 'O', '상업단지']
# ['OK프로틴바', '서울', '서울', '성동구', '6500', 'O', '주거단지']
# ['여의도프로틴연구소', '서울', '서울', '영등포구', '5900', 'O', '상업단지']
# ['프로프로틴', '경기', '고양', '덕양구', '5500', 'O', '주거단지']
# ['프로틴카페 H247', '서울', '서울', '강남구', '7000', 'O', '상업단지']
# ['프로틴퀸코리아', '서울', '서울', '강남구', '7000', 'O', '상업단지']
# ['올라프로틴', '서울', '서울', '강남구', '7000', 'O', '상업단지']
# ['스마일 프로틴', '서울', '서울', '종로구', '6500', 'O', '상업단지']
# ['하이프로틴', '경기', '남양주', '다산동', '6000', 'O', '주거단지']
# ['헬로프로틴', '서울', '서울', '중랑구', '6000', 'O', '주거단지']
# ['써니프로틴', '경기', '구리', '인창동', '6500', 'O', '주거단지']
# ['하이프로틴 단백질카페 ', '인천', '인천', '남동구', '5000', 'O', '주거단지']
# ['프로틴도넛 하랑', '경기', '고양', '일산동구', '6000', 'O', '주거단지']
# ['예스프로틴', '서울', '서울', '도봉구', '6500', 'O', '주거단지']
# ['참쉬운프로틴cafe', '경기', '고양', '덕양구', '6200', 'O', '주거단지']
# ...
